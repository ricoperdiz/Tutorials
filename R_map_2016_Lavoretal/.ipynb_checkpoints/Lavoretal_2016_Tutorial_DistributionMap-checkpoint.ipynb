# %% [markdown]
# # Tutorial to print a distribution map for *Pilosocereus oligolepis* (Vaup.) Byles & Rowley, a Cactaceae, published at [Lavor et al. (2016)](https://bioone.org/journals/Cactus-and-Succulent-Journal/volume-88/issue-3/015.088.0306/Rediscovery-of-iPilosocereus-oligolepsis-i-Cactaceae-in-the-State-of/10.2985/015.088.0306.short)
# ### Author: [Ricardo de Oliveira Perdiz](https://github.com/ricoperdiz/CV), Ph.D. student in Botany, [Department of Botany](http://www.portais.atrio.scire.net.br/inpa-ppgbot/), National Institute for Amazon Research ([INPA](http://portal.inpa.gov.br/)), Manaus, AM, Brazil
#
# If you get interest on this paper, entitled **Rediscovery of _Pilosocereus oligolepsis_ (Cactaceae) in the State of Roraima, Brazil** ([Lavor et al. (2016)](https://bioone.org/journals/Cactus-and-Succulent-Journal/volume-88/issue-3/015.088.0306/Rediscovery-of-iPilosocereus-oligolepsis-i-Cactaceae-in-the-State-of/10.2985/015.088.0306.short)), you can have access to it [here](https://www.researchgate.net/publication/304000968_Rediscovery_of_Pilosocereus_oligolepsis_Cactaceae_in_the_State_of_Roraima_Brazil?_sg=gfXhiYuct7e0AfUnueYX2h0szNsGWSXRVsdBtxA_wybL80YkEiAkktnKrTNqFPjzuxIVbU2Vof1vTBVGC0xumQmgfPaQS7pxLth074k_.p6brM0HryaBic4Z4__NyXYwZq_86NFfvCiw6nNol3h9J5ENqmTIsaKbHt2eiFtseHjhsnh4iatb-K4XebYBm1Q).

# %%
# ----------
## ATTENTION
# ----------

# ---------------------------------------------------------------
## ALL Data needed for plotting this map is available at: 
# <https://github.com/ricoperdiz/Tutorials/tree/master/R_map_2016_Lavoretal>
## Script author: Ricardo Perdiz <ricardoperdiz@yahoo.com>
## Any doubts or error, please leave an issue at <github.com/ricoperdiz/Tutorials/> or write an email.
# ---------------------------------------------------------------

# %% [markdown]
# ## 01 Load packages
#
# Make sure you have all packages below installed.

# %%
# list of packages needed for this tutorial
package_list <- c('maps', 'rgdal', 'maptools', 'foreign', 'GISTools', 'knitr')

# Run command below to install all packages inside vector package_list, in case you need it
#install.packages(package_list, dependencies = TRUE)
# Load packages
sapply(package_list, library, character.only = TRUE, logical.return = TRUE, quietly = TRUE, warn.conflicts = FALSE)
# If any of the messages below points FALSE, it means that you do not have that package installed. So, please install it before proceeding with the tutorial.
# if you do not remember how to install a package, use the command below
# install.packages("PackageName", dependencies = TRUE)
# Out:
#     maps    rgdal maptools  foreign GISTools    knitr
#     TRUE     TRUE     TRUE     TRUE     TRUE     TRUE

# %% [markdown]
# ## 02 Read data and create vectors
#
# Data needed for this tutorial is divided between specimen and GIS data. Specimen data contains coordinate points, while GIS contains all shapefiles needed for the maps.
#
#
# ### Specimen data

# %%
# read data and create vectors

# ----------------------
## Data for overview map
# ----------------------

# Vectors with coordinate range
x1 <- c(-80,-40)
y1 <- c(-20,10)

# %%
# Load shapefile for P. oligolepis occurrence area
area_mapa <- readShapePoly('area_mapa_piloso_oligolepis')
# Out:
# Warning message:
# “readShapePoly is deprecated; use rgdal::readOGR or sf::st_read”

# %%
# Retrieve data for British Guyana 
guy <- subset(area_mapa, GEOUNIT == 'Guyana')

# %%
# Load shapefile of Roraima state, Brazil
rr <- readShapePoly('roraima')
# Out:
# Warning message:
# “readShapePoly is deprecated; use rgdal::readOGR or sf::st_read”

# %%
# Shapefile with rivers in RR
rios_rr <- rgdal::readOGR('.','rios_para_Piloso_oligolepis', encoding = 'latin1')
# Out:
# OGR data source with driver: ESRI Shapefile
# Source: "/Users/ricoperdiz/Documents/Tutorials/R_map_2016_Lavoretal", layer: "rios_para_Piloso_oligolepis"
# with 162 features
# It has 4 fields

# %%
# Pilosocereus oligolepis collections
coord <- read.table('coord.csv', header = T, as.is = TRUE, sep = '\t')
coord
# Out:
#   COLETOR           NUMERO LAT      LONG      ALTITUDE
# 1 Lavor, P.           60   2.322600 -60.47489  NA
# 2 Lavor, P.           67   2.323590 -60.47484  NA
# 3 Esforço de coleta   NA   2.413900 -60.31990  NA
# 4 Esforço de coleta   NA   2.345620 -60.21585  NA
# 5 Lavor, P.           69   3.485320 -60.59020  NA
# 6 Esforço de coleta   NA   2.531650 -60.40456  NA
# 7 Esforço de coleta   NA   3.377960 -59.82732  NA
# 8 Smith             3380   4.908333 -58.91667 150
#   LOCALIDADE                     OCORRE LEGENDA
# 1 Serra grande - RR- Cantá       1      Novos registros
# 2 Serra grande - RR- Cantá       1      Novos registros
# 3 Serra da Lua - RR - Catá       0      Locais visitados mas sem registro
# 4 Serra da Lua - RR - Catá       0      Locais visitados mas sem registro
# 5 Serra do Tabaco - RR - Amajari 1      Novos registros
# 6 Serra da Moça - RR - Boa Vista 0      Locais visitados mas sem registro
# 7 Bonfim - RR                    0      Locais visitados mas sem registro
# 8 GUIANA INGLESA                 1      Localidade tipo de P. kanukuensis

# %%
coord_boavista <- read.table('coord_boavista.csv', header = T, as.is = T, sep = '\t')
coord_boavista
# Out:
#   NM_MUNICIP LONG      LAT      ALT      coords.x1 coords.x2 optional
# 1 BOA VISTA  -60.67053 2.816682 79.82823 -60.67053 2.816682  TRUE
# 2 CANTÁ      -60.60206 2.607666 82.98280 -60.60206 2.607666  TRUE

# %%
# Vector to create a legend
legendas <- unique(coord$LEGENDA)
legendas
# Out:
# [1] "Novos registros"                   "Locais visitados mas sem registro"
# [3] "Localidade tipo de P. kanukuensis"

# %%
# Coordinates for map 2 - *Pilosocereus oligolepis* distribution
y2 <- round(range(coord$LAT)) + c(-0.5,0.5)
x2 <- round(range(coord$LONG)) + c(-0.5, 0.5)

# %%
# Vector for point shapes
pontos <- c(17, 2, 11)

# %%
# Vector for point sizes
cex_tam <- seq(0.8, 1.6, by = 0.1)
cex_tam
# Out:
# [1] 0.8 0.9 1.0 1.1 1.2 1.3 1.4 1.5 1.6

# %%
# Vector for colors in legend
cores_leg <- c(rep('black',5),'grey80')

# %% [markdown]
# ### 03 Plot the maps and the legend one by one
#
# #### Plot number 1 - Overview map

# %%
# plot number 1 - Overview map
par(mar = c(0,2,2,2))
plot(area_mapa, xlim = x1, ylim = y1, col = 'white')
plot(rr, add = TRUE, col = 'gray70')
par(cex = 1, las = 1)
# Add North arrow
GISTools::north.arrow(-45,5, len = 1, cex.lab = 0.9,lab = 'N', col = 'black')
# Add a text 
text(-58, -10, labels ='BRAZIL', pos = 4, cex = cex_tam[1], font = 2)
box()
# Out:
# plot without title

# %% [markdown]
# #### Plot number 2 - *Pilosocereus oligolepis* distribution
#
# Note that the scale bar does not appear to be correct. However it will fit nicely in the final layout of this map, when we combine all three plots. Check below.

# %%
# plot number 2 - Pilosocereus oligolepis distribution
par(mar = c(2,2,2,3))

plot(area_mapa, xlim = x2, ylim = y2, lwd = 1.2)
plot(rr, add = T, col = 'gray70', lwd = 1.2)
# Plot rivers
plot(rios_rr, add = T, border = 'gray80', lwd = 0.8)

# For loop to plot points with different shapesloop para plotar pontos com shapes diferentes
for(p in seq_along(legendas)) {
    
    points(coord$LONG[coord$LEGENDA == legendas[p]], coord$LAT[coord$LEGENDA == legendas[p]], pch = pontos[p], cex = cex_tam[7], lwd = 1.4)
    
}

points(coord_boavista$LONG[1], coord_boavista$LAT[1], pch = 3,cex = cex_tam[6], font = 2, lwd = 2)

# Plot text
text(min(x2), min(y2), labels = 'BRAZIL', pos = 4, cex = cex_tam[5], font = 2)
text(coord$LONG[coord$LEGENDA == 'Localidade tipo de P. kanukuensis'], coord$LAT[coord$LEGENDA == 'Localidade tipo de P. kanukuensis'], labels = 'GUYANA', pos = 1, offset = 1, cex = cex_tam[5], font = 2)
text(min(x2) - 0.5, max(y2) - 0.5, labels = 'VENEZUELA', pos = 4, cex = cex_tam[5], font = 2)

par(cex = 1, las = 1)
# Add scale bar
maps::map.scale(max(x2) + 0.1, min(y2) + 0.1, ratio = F, cex = 1.2, metric = T, col = 'black')

# Add North arrow
GISTools::north.arrow(max(x2) + 1, min(y2) + 0.35, len = 0.08, lab = 'N', cex.lab = 1.2, lwd = 1.5, col = 'black')

# Add map axes
map.axes()
axis(side=4,las=1)
axis(side=3,las=1)
# Out:
# plot without title

# %% [markdown]
# #### Plot number 3 - LEGEND

# %%
# plot number 3 - LEGEND
par(mar = c(0,0,0,0))
plot.new()
par(cex = 1.2)
legend(x = 'center', ncol = 1, legend = c(expression(paste('New sites for ', italic('P. oligolepis'), sep = '')), 'Sites searched without records', 'Extra Brazil site', 'Boa Vista, capital city of Roraima', 'International borders', 'River courses'), 
       pch = c(pontos, 3, NA, NA), 
       col = cores_leg, 
       title = expression(paste(italic('Pilosocereus oligolepis'), '\n record data', sep='')), 
       lty = c(0, 0, 0, 0, 1, 1), 
       pt.lwd = 1.25, 
       lwd = 3, 
       text.width = 0.86, 
       y.intersp = 1.8, 
       box.col = 'black')
# Out:
# Warning message in strwidth(title, units = "user", cex = cex):
# “font metrics unknown for character 0xa”Warning message in text.default(x, y, ...):
# “font metrics unknown for character 0xa”Warning message in text.default(x, y, ...):
# “font metrics unknown for character 0xa”
# plot without title

# %% [markdown]
# ## 04 Combine all three plots and save them into one file
#
# We are going to use the function `layout` to combine all three plots into one. And let's use the function `pdf` to start a pdf and save the map locally.

# %%
##layout-----------------------------------------------------------------------------
par.norm <- par(no.readonly=T)
graphics.off()

# Start a pdf
pdf('final_map_Lavoretal_2016.pdf', height = 7, width = 14, onefile = T)

# Map layout
mapa.layout <- layout(matrix(c(1,1,2,2,2,2,2,2,3,3,2,2,2,2,2,2,3,3,2,2,2,2,2,2),nrow=3,byrow=T),widths=rep(2/8,8),heights=rep(1/3,3),respect=T)

# ----------------------------
# plot number 1 - Overview map
# ----------------------------

par(mar = c(0,2,2,2))
plot(area_mapa, xlim = x1, ylim = y1, col = 'white')
plot(rr, add = TRUE, col = 'gray70')
par(cex = 1, las = 1)
# Add North arrow
GISTools::north.arrow(-45,5, len = 1, cex.lab = 0.9,lab = 'N', col = 'black')
# Add a text 
text(-58, -10, labels ='BRAZIL', pos = 4, cex = cex_tam[1], font = 2)
box()

# ----------------------------------------------------
# plot number 2 - Pilosocereus oligolepis distribution
# ----------------------------------------------------

par(mar = c(2,2,2,3))
plot(area_mapa, xlim = x2, ylim = y2, lwd = 1.2)
plot(rr, add = T, col = 'gray70', lwd = 1.2)
# Plot rivers
plot(rios_rr, add = T, border = 'gray80', lwd = 0.8)

# For loop to plot points with different shapesloop para plotar pontos com shapes diferentes
for(p in seq_along(legendas)) {
    
    points(coord$LONG[coord$LEGENDA == legendas[p]], coord$LAT[coord$LEGENDA == legendas[p]], pch = pontos[p], cex = cex_tam[7], lwd = 1.4)
    
}

points(coord_boavista$LONG[1], coord_boavista$LAT[1], pch = 3,cex = cex_tam[6], font = 2, lwd = 2)

# Plot text
text(min(x2), min(y2), labels = 'BRAZIL', pos = 4, cex = cex_tam[5], font = 2)
text(coord$LONG[coord$LEGENDA == 'Localidade tipo de P. kanukuensis'], coord$LAT[coord$LEGENDA == 'Localidade tipo de P. kanukuensis'], labels = 'GUYANA', pos = 1, offset = 1, cex = cex_tam[5], font = 2)
text(min(x2) - 0.5, max(y2) - 0.5, labels = 'VENEZUELA', pos = 4, cex = cex_tam[5], font = 2)

par(cex = 1, las = 1)
# Add scale bar
maps::map.scale(max(x2) + 0.1, min(y2) + 0.1, ratio = F, cex = 1.2, metric = T, col = 'black')

# Add North arrow
GISTools::north.arrow(max(x2) + 1, min(y2) + 0.35, len = 0.08, lab = 'N', cex.lab = 1.2, lwd = 1.5, col = 'black')

# Add map axes
map.axes()
axis(side=4,las=1)
axis(side=3,las=1)


# ----------------------
# plot number 3 - LEGEND
# ----------------------

par(mar = c(0,0,0,0))
plot.new()
par(cex = 1.2)
legend(x = 'center', ncol = 1, legend = c(expression(paste('New sites for ', italic('P. oligolepis'), sep = '')), 'Sites searched without records', 'Extra Brazil site', 'Boa Vista, capital city of Roraima', 'International borders', 'River courses'), 
       pch = c(pontos, 3, NA, NA), 
       col = cores_leg, 
       title = expression(paste(italic('Pilosocereus oligolepis'), '\n record data', sep='')), 
       lty = c(0, 0, 0, 0, 1, 1), 
       pt.lwd = 1.25, 
       lwd = 3, 
       text.width = 0.86, 
       y.intersp = 1.8, 
       box.col = 'black')
#finaliza o layout
dev.off()
# Out:
# Warning message in strwidth(title, units = "user", cex = cex):
# “font metrics unknown for character 0xa”Warning message in text.default(x, y, ...):
# “font metrics unknown for character 0xa”Warning message in text.default(x, y, ...):
# “font metrics unknown for character 0xa”
# null device
#           1

# %% [markdown]
# I included in this folder a PNG version of this map, so you can check out below how it looks. Also, I recommend you to take a look at the published paper entitled **Rediscovery of _Pilosocereus oligolepsis_ (Cactaceae) in the State of Roraima, Brazil** ([Lavor et al. (2016)](https://bioone.org/journals/Cactus-and-Succulent-Journal/volume-88/issue-3/015.088.0306/Rediscovery-of-iPilosocereus-oligolepsis-i-Cactaceae-in-the-State-of/10.2985/015.088.0306.short)), by clicking [here](https://www.researchgate.net/publication/304000968_Rediscovery_of_Pilosocereus_oligolepsis_Cactaceae_in_the_State_of_Roraima_Brazil?_sg=gfXhiYuct7e0AfUnueYX2h0szNsGWSXRVsdBtxA_wybL80YkEiAkktnKrTNqFPjzuxIVbU2Vof1vTBVGC0xumQmgfPaQS7pxLth074k_.p6brM0HryaBic4Z4__NyXYwZq_86NFfvCiw6nNol3h9J5ENqmTIsaKbHt2eiFtseHjhsnh4iatb-K4XebYBm1Q).

# %% [markdown]
# ![Lavoretal_2016_DistributionMap_for_Pilosocereus_oligolepis](final_map_Lavoretal_2016.png)
